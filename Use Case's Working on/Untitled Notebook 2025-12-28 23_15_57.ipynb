# %%
#Child Node call from another Notebook:

import requests

response = requests.get(
    "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
)

dbutils.fs.put("/Volumes/workspace/databricks/mobile_usage/mobile_os_usage.csv", response.text, overwrite=True)
