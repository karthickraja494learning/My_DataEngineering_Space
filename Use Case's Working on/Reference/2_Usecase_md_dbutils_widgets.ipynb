# %%
# %python
base_path = "/Volumes/workspace/default/volume_36"
#Create raw_path, processed_path and archive_path as given below...
raw_path = f"{base_path}/raw"
processed_path = f"{base_path}/processed"
archive_path = f"{base_path}/archive"

# %%
# %sql
create volume if not exists workspace.default.volume_36

# %%
# %python
dbutils.fs.mkdirs(base_path)
dbutils.fs.mkdirs(raw_path)
dbutils.fs.mkdirs(processed_path)
dbutils.fs.mkdirs(archive_path)

# %%
# %python
dbutils.fs.put('/Volumes/workspace/default/volume_36/raw/health_care.txt',"patient_id,patient_name,age,gender\n1,John Doe,68,M\n2,Jane Smith,54,F", overwrite=True)

# %%
# %python

dbutils.fs.ls('/Volumes/workspace/default/volume_36/raw/')

# %%
dbutils.fs.cp('/Volumes/workspace/default/volume_36/raw/health_care.txt','/Volumes/workspace/default/volume_36/processed/')

# %%
dbutils.widgets.dropdown('environment','dev',['dev','prod'])

# %%
dbutils.widgets.text('owner','agesh')

# %%
env=dbutils.widgets.get('environment')
own=dbutils.widgets.get('owner')
print(env)
print(own)

# %%
dbutils.fs.mv('/Volumes/workspace/default/volume_36/processed/health_care.txt','/Volumes/workspace/default/volume_36/archive/')

# %%
# %run "/Workspace/Users/ageshkalesh@gmail.com/databricks/4_child_nb_dataload"

# %%
dbutils.notebook.exit('Pipeline completed successfully')
