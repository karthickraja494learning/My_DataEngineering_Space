# %%
# %py

import requests

request_data=requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
print(request_data.text)

dbutils.fs.put("/Volumes/workspace/default/volume_metrics/mobile_os_usage.csv",request_data.text,overwrite=True)
