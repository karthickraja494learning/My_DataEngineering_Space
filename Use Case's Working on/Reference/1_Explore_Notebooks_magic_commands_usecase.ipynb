# %% [markdown]
# #<span style= "color:orange;">_**databricks learning**_</span>
#
# ###<span style="color:blue;">*Agesh*</span>
#
# https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg
#
# ![team photo](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volume_metrics

# %%
# %run "/Workspace/Users/ageshkalesh@gmail.com/4_child_nb_dataload"

# %%
# %fs ls "/Volumes/workspace/default/volume_metrics"

# %%
# %python

df1= spark.read.csv("/Volumes/workspace/default/volume_metrics/mobile_os_usage.csv")

# %%
# %python

df1.write.saveAsTable("default.mobile_os_usage")

# %%
# %python
df_result=spark.sql("select * from default.mobile_os_usage")
display(df_result)

# %%
# %python

var1=str(input()).upper()
print(var1)

# %%
# %pip install pandas

# %%
# %python 
import pandas as pd

df=pd.read_csv("/Volumes/workspace/default/volume_metrics/mobile_os_usage.csv")
print(df)

# %%
# %sh
echo "Magic commands tasks completed"
